# %%
import zipfile

def validate_files(filepath):
    list_of_clean_reports = []

    with zipfile.ZipFile(filepath, "r") as z:
        files = z.namelist()
        for i, filename in enumerate(files, start=1):
            if '-ro-' not in filename:
                pass
            else:
                ext = filename.split('-ro-')[1]
                if len(ext) == 15:
                    list_of_clean_reports.append(filename)
                else:
                    pass

    return list_of_clean_reports


zip_files = validate_files("Colab.zip")

# %%
print(zip_files)
# Out:
# ['Colab/roarmy-adlunap-ro-2025-09-26.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-02.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-03.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-06.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-07.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-08.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-09.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-10.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-13.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-16.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-17.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-27.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-28.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-29.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-30.xlsx', 'Colab/roarmy-adlunap-ro-2025-10-31.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-03.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-04.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-05.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-06.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-14.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-17.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-18.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-19.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-20.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-21.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-25.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-26.xlsx', 'Colab/roarmy-adlunap-ro-2025-11-28.xlsx', 'Colab/roarmy-adlunap-ro-2025-12-03.xlsx', 'Colab/roarmy-adlunap-ro-2025-12-04.xlsx', 'Colab/roarmy-adlunap-ro-2025-12-05.xlsx', 'Colab/roarmy-adlunap-ro-2025-12-11.xlsx', 'Colab/roarmy-adlunap-ro-2025-12-12.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-15.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-19.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-20.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-21.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-23.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-26.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-27.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-29.xlsx', 'Colab/roarmy-adlunap-ro-2026-01-30.xlsx', 'Colab/roarmy-adlunap-ro-2026-02-02.xlsx', 'Colab/roarmy-adlunap-ro-2026-02-03.xlsx', 'Colab/roarmy-adlunap-ro-2026-02-04.xlsx', 'Colab/roarmy-adlunap-ro-2026-02-05.xlsx']
